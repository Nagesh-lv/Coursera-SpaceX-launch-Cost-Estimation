# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from bs4 import BeautifulSoup
import re
import unicodedata
import requests
import os
import datetime

# %% [markdown]
# ### get data from api

# %%
#Global variables
BoosterVersion = []
PayloadMass = []
Orbit = []
LaunchSite = []
Outcome = []
Flights = []
GridFins = []
Reused = []
Legs = []
LandingPad = []
Block = []
ReusedCount = []
Serial = []
Longitude = []
Latitude = []

# %%
url = 'https://api.spacexdata.com/v4/launches/past'
response = requests.get(url)
df = pd.json_normalize(response.json())

# %%
# Takes the dataset and uses the rocket column to call the API and append the data to the list
def getBoosterVersion(data):
    for rocket in data['rocket']:
       if rocket:
        response = requests.get("https://api.spacexdata.com/v4/rockets/"+str(rocket)).json()
        BoosterVersion.append(response['name'])

# %%
# Takes the dataset and uses the launchpad column to call the API and append the data to the list
def getLaunchSite(data):
    for pad in data['launchpad']:
       if pad:
         response = requests.get("https://api.spacexdata.com/v4/launchpads/"+str(pad)).json()
         Longitude.append(response['longitude'])
         Latitude.append(response['latitude'])
         LaunchSite.append(response['name'])

# %%
# Takes the dataset and uses the payloads column to call the API and append the data to the lists
def getPayloadData(data):
    for load in data['payloads']:
       if load:
        response = requests.get("https://api.spacexdata.com/v4/payloads/"+load).json()
        PayloadMass.append(response['mass_kg'])
        Orbit.append(response['orbit'])

# %%
# Takes the dataset and uses the cores column to call the API and append the data to the lists
def getCoreData(data):
    for core in data['cores']:
            if core['core'] != None:
                response = requests.get("https://api.spacexdata.com/v4/cores/"+core['core']).json()
                Block.append(response['block'])
                ReusedCount.append(response['reuse_count'])
                Serial.append(response['serial'])
            else:
                Block.append(None)
                ReusedCount.append(None)
                Serial.append(None)
            Outcome.append(str(core['landing_success'])+' '+str(core['landing_type']))
            Flights.append(core['flight'])
            GridFins.append(core['gridfins'])
            Reused.append(core['reused'])
            Legs.append(core['legs'])
            LandingPad.append(core['landpad'])

# %%
df.sample()
# Out:
#     static_fire_date_utc  static_fire_date_unix    net  window  \
# 128                 None                    NaN  False     0.0
#
#                        rocket success failures  \
# 128  5e9d0d95eda69973a809d1ec    True       []
#
#                                                details crew  \
# 128  SpaceX's 22nd ISS resupply mission on behalf o...   []
#
#                                                  ships  ...  \
# 128  [5ea6ed2f080df4000697c90b, 608c1a06cf7f3d61526...  ...
#
#     links.reddit.media                              links.reddit.recovery  \
# 128               None  https://www.reddit.com/r/spacex/comments/k2ts1...
#
#     links.flickr.small                              links.flickr.original  \
# 128                 []  [https://live.staticflickr.com/65535/512254820...
#
#     links.presskit                 links.webcast  links.youtube_id  \
# 128           None  https://youtu.be/QXf9mRWbXDM       QXf9mRWbXDM
#
#                                          links.article  \
# 128  https://spaceflightnow.com/2021/06/03/spacex-s...
#
#                                  links.wikipedia  fairings
# 128  https://en.wikipedia.org/wiki/SpaceX_CRS-22       NaN
#
# [1 rows x 43 columns]

# %%
data = df[['rocket', 'payloads', 'launchpad', 'cores', 'flight_number', 'date_utc']]

# %%
data = data[data['cores'].map(len)==1]
data = data[data['payloads'].map(len)==1]

# %%
data['cores'] = data['cores'].map(lambda x : x[0])
data['payloads'] = data['payloads'].map(lambda x : x[0])

# %%
data['date'] = pd.to_datetime(data['date_utc']).dt.date

# %%
data = data[data['date'] <= datetime.date(2020, 11, 13)]

# %%
getBoosterVersion(data)
getCoreData(data)
getLaunchSite(data)
getPayloadData(data)

# %%
launch_dict = {'FlightNumber': list(data['flight_number']),
'Date': list(data['date']),
'BoosterVersion':BoosterVersion,
'PayloadMass':PayloadMass,
'Orbit':Orbit,
'LaunchSite':LaunchSite,
'Outcome':Outcome,
'Flights':Flights,
'GridFins':GridFins,
'Reused':Reused,
'Legs':Legs,
'LandingPad':LandingPad,
'Block':Block,
'ReusedCount':ReusedCount,
'Serial':Serial,
'Longitude': Longitude,
'Latitude': Latitude}

# %%
df = pd.DataFrame(launch_dict)

# %%
df.sample(5)
# Out:
#     FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 11            15  2014-07-14       Falcon 9       1316.0   LEO  CCSFS SLC 40
# 4              6  2010-06-04       Falcon 9          NaN   LEO  CCSFS SLC 40
# 17            22  2015-04-14       Falcon 9       1898.0   ISS  CCSFS SLC 40
# 80            92  2020-03-18       Falcon 9      15600.0  VLEO    KSC LC 39A
# 82            94  2020-05-30       Falcon 9       9525.0   ISS    KSC LC 39A
#
#        Outcome  Flights  GridFins  Reused   Legs                LandingPad  \
# 11  True Ocean        1     False   False   True                      None
# 4    None None        1     False   False  False                      None
# 17  False ASDS        1      True   False   True  5e9e3032383ecb761634e7cb
# 80  False ASDS        5      True    True   True  5e9e3032383ecb6bb234e7ca
# 82   True ASDS        1      True   False   True  5e9e3032383ecb6bb234e7ca
#
#     Block  ReusedCount Serial  Longitude   Latitude
# 11    1.0            0  B1007 -80.577366  28.561857
# 4     1.0            0  B0003 -80.577366  28.561857
# 17    1.0            0  B1015 -80.577366  28.561857
# 80    5.0            4  B1048 -80.603956  28.608058
# 82    5.0           13  B1058 -80.603956  28.608058

# %% [markdown]
# ### Filter the dataframe to only include `Falcon 9` launches

# %%
data_falcon9 = df[df['BoosterVersion']=='Falcon 9']

# %% [markdown]
# Now that we have removed some values we should reset the FlgihtNumber column

# %%
data_falcon9.loc[:,'FlightNumber'] = list(range(1, data_falcon9.shape[0]+1))
data_falcon9.head(5)
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 4             1  2010-06-04       Falcon 9          NaN   LEO  CCSFS SLC 40
# 5             2  2012-05-22       Falcon 9        525.0   LEO  CCSFS SLC 40
# 6             3  2013-03-01       Falcon 9        677.0   ISS  CCSFS SLC 40
# 7             4  2013-09-29       Falcon 9        500.0    PO   VAFB SLC 4E
# 8             5  2013-12-03       Falcon 9       3170.0   GTO  CCSFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 4    None None        1     False   False  False       None    1.0
# 5    None None        1     False   False  False       None    1.0
# 6    None None        1     False   False  False       None    1.0
# 7  False Ocean        1     False   False  False       None    1.0
# 8    None None        1     False   False  False       None    1.0
#
#    ReusedCount Serial   Longitude   Latitude
# 4            0  B0003  -80.577366  28.561857
# 5            0  B0005  -80.577366  28.561857
# 6            0  B0007  -80.577366  28.561857
# 7            0  B1003 -120.610829  34.632093
# 8            0  B1004  -80.577366  28.561857

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# We can see below that some of the rows are missing values in our dataset.

# %%
data_falcon9.isnull().sum()
# Out:
# FlightNumber       0
# Date               0
# BoosterVersion     0
# PayloadMass        5
# Orbit              0
# LaunchSite         0
# Outcome            0
# Flights            0
# GridFins           0
# Reused             0
# Legs               0
# LandingPad        26
# Block              0
# ReusedCount        0
# Serial             0
# Longitude          0
# Latitude           0
# dtype: int64

# %% [markdown]
# Before we can continue we must deal with these missing values. The <code>LandingPad</code> column will retain None values to represent when landing pads were not used.

# %% [markdown]
# ### Task 3: Dealing with Missing Values

# %% [markdown]
# Calculate below the mean for the <code>PayloadMass</code> using the <code>.mean()</code>. Then use the mean and the <code>.replace()</code> function to replace `np.nan` values in the data with the mean you calculated.

# %% [markdown]
# #### Calculating the mean value of PayloadMass column
# #### Replacing the np.nan values with its mean value

# %%
mean = data_falcon9['PayloadMass'].mean()
data_falcon9['PayloadMass'].fillna(mean, inplace=True)
# Out:
# <ipython-input-165-1e56d05301c6>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_falcon9['PayloadMass'].fillna(mean, inplace=True)

# %% [markdown]
# You should see the number of missing values of the <code>PayLoadMass</code> change to zero.

# %%
data_falcon9.isnull().sum()
# Out:
# FlightNumber       0
# Date               0
# BoosterVersion     0
# PayloadMass        0
# Orbit              0
# LaunchSite         0
# Outcome            0
# Flights            0
# GridFins           0
# Reused             0
# Legs               0
# LandingPad        26
# Block              0
# ReusedCount        0
# Serial             0
# Longitude          0
# Latitude           0
# Class              0
# dtype: int64

# %%
df = data_falcon9

# %%
df.isnull().sum()/len(df)*100
# Out:
# FlightNumber       0.000000
# Date               0.000000
# BoosterVersion     0.000000
# PayloadMass        0.000000
# Orbit              0.000000
# LaunchSite         0.000000
# Outcome            0.000000
# Flights            0.000000
# GridFins           0.000000
# Reused             0.000000
# Legs               0.000000
# LandingPad        28.888889
# Block              0.000000
# ReusedCount        0.000000
# Serial             0.000000
# Longitude          0.000000
# Latitude           0.000000
# Class              0.000000
# dtype: float64

# %%
df['LaunchSite'].value_counts()
# Out:
# LaunchSite
# CCSFS SLC 40    55
# KSC LC 39A      22
# VAFB SLC 4E     13
# Name: count, dtype: int64

# %%
df['Orbit'].value_counts()
# Out:
# Orbit
# GTO      27
# ISS      21
# VLEO     14
# PO        9
# LEO       7
# SSO       5
# MEO       3
# ES-L1     1
# HEO       1
# SO        1
# GEO       1
# Name: count, dtype: int64

# %%
landing_outcomes = df['Outcome'].value_counts()

# %%
for i,outcome in enumerate(landing_outcomes.keys()):
    print(i,outcome)
# Out:
# 0 True ASDS
# 1 None None
# 2 True RTLS
# 3 False ASDS
# 4 True Ocean
# 5 False Ocean
# 6 None ASDS
# 7 False RTLS

# %%
bad_outcomes = set(landing_outcomes.keys()[[1,3,5,6,7]])
bad_outcomes
# Out:
# {'False ASDS', 'False Ocean', 'False RTLS', 'None ASDS', 'None None'}

# %%
landing_class = []
for i in df['Outcome']:
    if i in bad_outcomes:
        landing_class.append(0)
    else:
        landing_class.append(1)
landing_class;

# %%
df['Class'] = landing_class

# %%
df['Class'].value_counts()
# Out:
# Class
# 1    60
# 0    30
# Name: count, dtype: int64

# %%
df['Class'].mean()
# Out:
# 0.6666666666666666

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# %sql sqlite:///my_data1.db

# %%
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 90

# %%
# %sql DROP TABLE IF EXISTS SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql CREATE TABLE SPACEXTABLE AS SELECT * FROM SPACEXTBL WHERE DATE IS NOT NULL
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql select distinct LaunchSite from spacextbl
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCSFS SLC 40',), ('VAFB SLC 4E',), ('KSC LC 39A',)]

# %%
# %%sql select * from SPACEXTBL
#       where launchsite like 'CCA%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %%sql select * from spacextbl
#       where outcome like 'True%'
#       order by date
#       limit 1
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(7, '2014-04-18', 'Falcon 9', 2296.0, 'ISS', 'CCSFS SLC 40', 'True Ocean', 1, 0, 0, 1, None, 1.0, 0, 'B1006', -80.577366, 28.5618571, 1)]

# %%
# %%sql select BoosterVersion from spacextbl
#       where outcome like 'True asds' and payloadmass between 4000 and 6000
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Falcon 9',),
#  ('Falcon 9',),
#  ('Falcon 9',),
#  ('Falcon 9',),
#  ('Falcon 9',),
#  ('Falcon 9',),
#  ('Falcon 9',)]

# %%
# %sql select * from spacextbl
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(1, '2010-06-04', 'Falcon 9', 6123.547647058824, 'LEO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B0003', -80.577366, 28.5618571, 0),
#  (2, '2012-05-22', 'Falcon 9', 525.0, 'LEO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B0005', -80.577366, 28.5618571, 0),
#  (3, '2013-03-01', 'Falcon 9', 677.0, 'ISS', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B0007', -80.577366, 28.5618571, 0),
#  (4, '2013-09-29', 'Falcon 9', 500.0, 'PO', 'VAFB SLC 4E', 'False Ocean', 1, 0, 0, 0, None, 1.0, 0, 'B1003', -120.610829, 34.632093, 0),
#  (5, '2013-12-03', 'Falcon 9', 3170.0, 'GTO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B1004', -80.577366, 28.5618571, 0),
#  (6, '2014-01-06', 'Falcon 9', 3325.0, 'GTO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B1005', -80.577366, 28.5618571, 0),
#  (7, '2014-04-18', 'Falcon 9', 2296.0, 'ISS', 'CCSFS SLC 40', 'True Ocean', 1, 0, 0, 1, None, 1.0, 0, 'B1006', -80.577366, 28.5618571, 1),
#  (8, '2014-07-14', 'Falcon 9', 1316.0, 'LEO', 'CCSFS SLC 40', 'True Ocean', 1, 0, 0, 1, None, 1.0, 0, 'B1007', -80.577366, 28.5618571, 1),
#  (9, '2014-08-05', 'Falcon 9', 4535.0, 'GTO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B1008', -80.577366, 28.5618571, 0),
#  (10, '2014-09-07', 'Falcon 9', 4428.0, 'GTO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B1011', -80.577366, 28.5618571, 0),
#  (11, '2014-09-21', 'Falcon 9', 2216.0, 'ISS', 'CCSFS SLC 40', 'False Ocean', 1, 0, 0, 0, None, 1.0, 0, 'B1010', -80.577366, 28.5618571, 0),
#  (12, '2015-01-10', 'Falcon 9', 2395.0, 'ISS', 'CCSFS SLC 40', 'False ASDS', 1, 1, 0, 1, '5e9e3032383ecb761634e7cb', 1.0, 0, 'B1012', -80.577366, 28.5618571, 0),
#  (13, '2015-02-11', 'Falcon 9', 570.0, 'ES-L1', 'CCSFS SLC 40', 'True Ocean', 1, 1, 0, 1, None, 1.0, 0, 'B1013', -80.577366, 28.5618571, 1),
#  (14, '2015-04-14', 'Falcon 9', 1898.0, 'ISS', 'CCSFS SLC 40', 'False ASDS', 1, 1, 0, 1, '5e9e3032383ecb761634e7cb', 1.0, 0, 'B1015', -80.577366, 28.5618571, 0),
#  (15, '2015-04-27', 'Falcon 9', 4707.0, 'GTO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B1016', -80.577366, 28.5618571, 0),
#  (16, '2015-06-28', 'Falcon 9', 2477.0, 'ISS', 'CCSFS SLC 40', 'None ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 1.0, 0, 'B1018', -80.577366, 28.5618571, 0),
#  (17, '2015-12-22', 'Falcon 9', 2034.0, 'LEO', 'CCSFS SLC 40', 'True RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 1.0, 0, 'B1019', -80.577366, 28.5618571, 1),
#  (18, '2016-01-17', 'Falcon 9', 553.0, 'PO', 'VAFB SLC 4E', 'False ASDS', 1, 1, 0, 1, '5e9e3033383ecbb9e534e7cc', 1.0, 0, 'B1017', -120.610829, 34.632093, 0),
#  (19, '2016-03-04', 'Falcon 9', 5271.0, 'GTO', 'CCSFS SLC 40', 'False ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 1.0, 0, 'B1020', -80.577366, 28.5618571, 0),
#  (20, '2016-04-08', 'Falcon 9', 3136.0, 'ISS', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 2.0, 1, 'B1021', -80.577366, 28.5618571, 1),
#  (21, '2016-05-06', 'Falcon 9', 4696.0, 'GTO', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 2.0, 0, 'B1022', -80.577366, 28.5618571, 1),
#  (22, '2016-05-27', 'Falcon 9', 3100.0, 'GTO', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 2.0, 1, 'B1023', -80.577366, 28.5618571, 1),
#  (23, '2016-07-18', 'Falcon 9', 2257.0, 'ISS', 'CCSFS SLC 40', 'True RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 2.0, 1, 'B1025', -80.577366, 28.5618571, 1),
#  (24, '2016-08-14', 'Falcon 9', 4600.0, 'GTO', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 2.0, 0, 'B1026', -80.577366, 28.5618571, 1),
#  (25, '2016-09-01', 'Falcon 9', 5500.0, 'GTO', 'CCSFS SLC 40', 'None ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 3.0, 0, 'B1028', -80.577366, 28.5618571, 0),
#  (26, '2017-01-14', 'Falcon 9', 9600.0, 'PO', 'VAFB SLC 4E', 'True ASDS', 1, 1, 0, 1, '5e9e3033383ecbb9e534e7cc', 3.0, 1, 'B1029', -120.610829, 34.632093, 1),
#  (27, '2017-02-19', 'Falcon 9', 2490.0, 'ISS', 'KSC LC 39A', 'True RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 3.0, 1, 'B1031', -80.6039558, 28.6080585, 1),
#  (28, '2017-03-16', 'Falcon 9', 5600.0, 'GTO', 'KSC LC 39A', 'None None', 1, 0, 0, 0, None, 3.0, 0, 'B1030', -80.6039558, 28.6080585, 0),
#  (29, '2017-03-30', 'Falcon 9', 5300.0, 'GTO', 'KSC LC 39A', 'True ASDS', 2, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 2.0, 1, 'B1021', -80.6039558, 28.6080585, 1),
#  (30, '2017-05-01', 'Falcon 9', 6123.547647058824, 'LEO', 'KSC LC 39A', 'True RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 3.0, 1, 'B1032', -80.6039558, 28.6080585, 1),
#  (31, '2017-05-15', 'Falcon 9', 6070.0, 'GTO', 'KSC LC 39A', 'None None', 1, 0, 0, 0, None, 3.0, 0, 'B1034', -80.6039558, 28.6080585, 0),
#  (32, '2017-06-03', 'Falcon 9', 2708.0, 'ISS', 'KSC LC 39A', 'True RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 3.0, 1, 'B1035', -80.6039558, 28.6080585, 1),
#  (33, '2017-06-23', 'Falcon 9', 3669.0, 'GTO', 'KSC LC 39A', 'True ASDS', 2, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 3.0, 1, 'B1029', -80.6039558, 28.6080585, 1),
#  (34, '2017-06-25', 'Falcon 9', 9600.0, 'PO', 'VAFB SLC 4E', 'True ASDS', 1, 1, 0, 1, '5e9e3033383ecbb9e534e7cc', 3.0, 1, 'B1036', -120.610829, 34.632093, 1),
#  (35, '2017-07-05', 'Falcon 9', 6761.0, 'GTO', 'KSC LC 39A', 'None None', 1, 0, 0, 0, None, 3.0, 0, 'B1037', -80.6039558, 28.6080585, 0),
#  (36, '2017-08-14', 'Falcon 9', 2910.0, 'ISS', 'KSC LC 39A', 'True RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 4.0, 1, 'B1039', -80.6039558, 28.6080585, 1),
#  (37, '2017-08-24', 'Falcon 9', 475.0, 'SSO', 'VAFB SLC 4E', 'True ASDS', 1, 1, 0, 1, '5e9e3033383ecbb9e534e7cc', 3.0, 1, 'B1038', -120.610829, 34.632093, 1),
#  (38, '2017-09-07', 'Falcon 9', 4990.0, 'LEO', 'KSC LC 39A', 'True RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 4.0, 1, 'B1040', -80.6039558, 28.6080585, 1),
#  (39, '2017-10-09', 'Falcon 9', 9600.0, 'PO', 'VAFB SLC 4E', 'True ASDS', 1, 1, 0, 1, '5e9e3033383ecbb9e534e7cc', 4.0, 1, 'B1041', -120.610829, 34.632093, 1),
#  (40, '2017-10-11', 'Falcon 9', 5200.0, 'GTO', 'KSC LC 39A', 'True ASDS', 2, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 3.0, 1, 'B1031', -80.6039558, 28.6080585, 1),
#  (41, '2017-10-30', 'Falcon 9', 3700.0, 'GTO', 'KSC LC 39A', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 4.0, 0, 'B1042', -80.6039558, 28.6080585, 1),
#  (42, '2017-12-15', 'Falcon 9', 2205.0, 'ISS', 'CCSFS SLC 40', 'True RTLS', 2, 1, 1, 1, '5e9e3032383ecb267a34e7c7', 3.0, 1, 'B1035', -80.577366, 28.5618571, 1),
#  (43, '2017-12-23', 'Falcon 9', 9600.0, 'PO', 'VAFB SLC 4E', 'True Ocean', 2, 1, 1, 0, None, 3.0, 1, 'B1036', -120.610829, 34.632093, 1),
#  (44, '2018-01-08', 'Falcon 9', 6123.547647058824, 'LEO', 'CCSFS SLC 40', 'True RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 4.0, 1, 'B1043', -80.577366, 28.5618571, 1),
#  (45, '2018-01-31', 'Falcon 9', 4230.0, 'GTO', 'CCSFS SLC 40', 'True Ocean', 2, 1, 1, 1, None, 3.0, 1, 'B1032', -80.577366, 28.5618571, 1),
#  (46, '2018-03-06', 'Falcon 9', 6092.0, 'GTO', 'CCSFS SLC 40', 'None None', 1, 1, 0, 1, None, 4.0, 0, 'B1044', -80.577366, 28.5618571, 0),
#  (47, '2018-03-30', 'Falcon 9', 9600.0, 'PO', 'VAFB SLC 4E', 'None None', 2, 1, 1, 1, None, 4.0, 1, 'B1041', -120.610829, 34.632093, 0),
#  (48, '2018-04-02', 'Falcon 9', 2760.0, 'ISS', 'CCSFS SLC 40', 'None None', 2, 1, 1, 1, None, 4.0, 1, 'B1039', -80.577366, 28.5618571, 0),
#  (49, '2018-04-18', 'Falcon 9', 350.0, 'HEO', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 4.0, 1, 'B1045', -80.577366, 28.5618571, 1),
#  (50, '2018-05-11', 'Falcon 9', 3750.0, 'GTO', 'KSC LC 39A', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 3, 'B1046', -80.6039558, 28.6080585, 1),
#  (51, '2018-06-04', 'Falcon 9', 5383.85, 'GTO', 'CCSFS SLC 40', 'None None', 2, 0, 1, 0, None, 4.0, 1, 'B1040', -80.577366, 28.5618571, 0),
#  (52, '2018-06-29', 'Falcon 9', 2410.0, 'ISS', 'CCSFS SLC 40', 'None None', 2, 0, 1, 0, None, 4.0, 1, 'B1045', -80.577366, 28.5618571, 0),
#  (53, '2018-07-22', 'Falcon 9', 7076.0, 'GTO', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 2, 'B1047', -80.577366, 28.5618571, 1),
#  (54, '2018-07-25', 'Falcon 9', 9600.0, 'PO', 'VAFB SLC 4E', 'True ASDS', 1, 1, 0, 1, '5e9e3033383ecbb9e534e7cc', 5.0, 4, 'B1048', -120.610829, 34.632093, 1),
#  (55, '2018-08-07', 'Falcon 9', 5800.0, 'GTO', 'CCSFS SLC 40', 'True ASDS', 2, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 3, 'B1046', -80.577366, 28.5618571, 1),
#  (56, '2018-09-10', 'Falcon 9', 7060.0, 'GTO', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 9, 'B1049', -80.577366, 28.5618571, 1),
#  (57, '2018-10-08', 'Falcon 9', 2800.0, 'SSO', 'VAFB SLC 4E', 'True RTLS', 2, 1, 1, 1, '5e9e3032383ecb554034e7c9', 5.0, 4, 'B1048', -120.610829, 34.632093, 1),
#  (58, '2018-11-15', 'Falcon 9', 3000.0, 'GTO', 'KSC LC 39A', 'True ASDS', 2, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 2, 'B1047', -80.6039558, 28.6080585, 1),
#  (59, '2018-12-03', 'Falcon 9', 4000.0, 'SSO', 'VAFB SLC 4E', 'True ASDS', 3, 1, 1, 1, '5e9e3033383ecbb9e534e7cc', 5.0, 3, 'B1046', -120.610829, 34.632093, 1),
#  (60, '2018-12-05', 'Falcon 9', 2573.0, 'ISS', 'CCSFS SLC 40', 'False RTLS', 1, 1, 0, 1, '5e9e3032383ecb267a34e7c7', 5.0, 0, 'B1050', -80.577366, 28.5618571, 0),
#  (61, '2018-12-23', 'Falcon 9', 4400.0, 'MEO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 5.0, 0, 'B1054', -80.577366, 28.5618571, 0),
#  (62, '2019-01-11', 'Falcon 9', 9600.0, 'PO', 'VAFB SLC 4E', 'True ASDS', 2, 1, 1, 1, '5e9e3033383ecbb9e534e7cc', 5.0, 9, 'B1049', -120.610829, 34.632093, 1),
#  (63, '2019-03-02', 'Falcon 9', 12259.0, 'ISS', 'KSC LC 39A', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 12, 'B1051', -80.6039558, 28.6080585, 1),
#  (64, '2019-05-04', 'Falcon 9', 2482.0, 'ISS', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 3, 'B1056', -80.577366, 28.5618571, 1),
#  (65, '2019-05-24', 'Falcon 9', 13200.0, 'VLEO', 'CCSFS SLC 40', 'True ASDS', 3, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 9, 'B1049', -80.577366, 28.5618571, 1),
#  (66, '2019-06-12', 'Falcon 9', 1425.0, 'SSO', 'VAFB SLC 4E', 'True RTLS', 2, 1, 1, 1, '5e9e3032383ecb554034e7c9', 5.0, 12, 'B1051', -120.610829, 34.632093, 1),
#  (67, '2019-07-25', 'Falcon 9', 2227.7, 'ISS', 'CCSFS SLC 40', 'True RTLS', 2, 1, 1, 1, '5e9e3032383ecb267a34e7c7', 5.0, 3, 'B1056', -80.577366, 28.5618571, 1),
#  (68, '2019-08-06', 'Falcon 9', 6500.0, 'GTO', 'CCSFS SLC 40', 'None None', 3, 0, 1, 0, None, 5.0, 2, 'B1047', -80.577366, 28.5618571, 0),
#  (69, '2019-11-11', 'Falcon 9', 15600.0, 'VLEO', 'CCSFS SLC 40', 'True ASDS', 4, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 4, 'B1048', -80.577366, 28.5618571, 1),
#  (70, '2019-12-05', 'Falcon 9', 5000.0, 'ISS', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 5, 'B1059', -80.577366, 28.5618571, 1),
#  (71, '2019-12-17', 'Falcon 9', 6800.0, 'GTO', 'CCSFS SLC 40', 'True ASDS', 3, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 3, 'B1056', -80.577366, 28.5618571, 1),
#  (72, '2020-01-07', 'Falcon 9', 15600.0, 'VLEO', 'CCSFS SLC 40', 'True ASDS', 4, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 9, 'B1049', -80.577366, 28.5618571, 1),
#  (73, '2020-01-19', 'Falcon 9', 6123.547647058824, 'SO', 'KSC LC 39A', 'None None', 4, 0, 1, 0, None, 5.0, 3, 'B1046', -80.6039558, 28.6080585, 0),
#  (74, '2020-01-29', 'Falcon 9', 15600.0, 'VLEO', 'CCSFS SLC 40', 'True ASDS', 3, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 12, 'B1051', -80.577366, 28.5618571, 1),
#  (75, '2020-02-17', 'Falcon 9', 15600.0, 'VLEO', 'CCSFS SLC 40', 'False ASDS', 4, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 3, 'B1056', -80.577366, 28.5618571, 0),
#  (76, '2020-03-07', 'Falcon 9', 1977.0, 'ISS', 'CCSFS SLC 40', 'True RTLS', 2, 1, 1, 1, '5e9e3032383ecb267a34e7c7', 5.0, 5, 'B1059', -80.577366, 28.5618571, 1),
#  (77, '2020-03-18', 'Falcon 9', 15600.0, 'VLEO', 'KSC LC 39A', 'False ASDS', 5, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 4, 'B1048', -80.6039558, 28.6080585, 0),
#  (78, '2020-04-22', 'Falcon 9', 15600.0, 'VLEO', 'KSC LC 39A', 'True ASDS', 4, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 12, 'B1051', -80.6039558, 28.6080585, 1),
#  (79, '2020-05-30', 'Falcon 9', 9525.0, 'ISS', 'KSC LC 39A', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 13, 'B1058', -80.6039558, 28.6080585, 1),
#  (80, '2020-06-04', 'Falcon 9', 15600.0, 'VLEO', 'CCSFS SLC 40', 'True ASDS', 5, 1, 1, 1, '5e9e3033383ecbb9e534e7cc', 5.0, 9, 'B1049', -80.577366, 28.5618571, 1),
#  (81, '2020-06-13', 'Falcon 9', 15600.0, 'VLEO', 'CCSFS SLC 40', 'True ASDS', 3, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 5, 'B1059', -80.577366, 28.5618571, 1),
#  (82, '2020-06-30', 'Falcon 9', 3880.0, 'MEO', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3033383ecbb9e534e7cc', 5.0, 12, 'B1060', -80.577366, 28.5618571, 1),
#  (83, '2020-07-20', 'Falcon 9', 6123.547647058824, 'GEO', 'CCSFS SLC 40', 'True ASDS', 2, 1, 1, 1, '5e9e3033383ecbb9e534e7cc', 5.0, 13, 'B1058', -80.577366, 28.5618571, 1),
#  (84, '2020-08-18', 'Falcon 9', 15600.0, 'VLEO', 'CCSFS SLC 40', 'True ASDS', 6, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 9, 'B1049', -80.577366, 28.5618571, 1),
#  (85, '2020-08-30', 'Falcon 9', 1600.0, 'SSO', 'CCSFS SLC 40', 'True RTLS', 4, 1, 1, 1, '5e9e3032383ecb267a34e7c7', 5.0, 5, 'B1059', -80.577366, 28.5618571, 1),
#  (86, '2020-09-03', 'Falcon 9', 15600.0, 'VLEO', 'KSC LC 39A', 'True ASDS', 2, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 12, 'B1060', -80.6039558, 28.6080585, 1),
#  (87, '2020-10-06', 'Falcon 9', 15600.0, 'VLEO', 'KSC LC 39A', 'True ASDS', 3, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 13, 'B1058', -80.6039558, 28.6080585, 1),
#  (88, '2020-10-18', 'Falcon 9', 15600.0, 'VLEO', 'KSC LC 39A', 'True ASDS', 6, 1, 1, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 12, 'B1051', -80.6039558, 28.6080585, 1),
#  (89, '2020-10-24', 'Falcon 9', 15600.0, 'VLEO', 'CCSFS SLC 40', 'True ASDS', 3, 1, 1, 1, '5e9e3033383ecbb9e534e7cc', 5.0, 12, 'B1060', -80.577366, 28.5618571, 1),
#  (90, '2020-11-05', 'Falcon 9', 3681.0, 'MEO', 'CCSFS SLC 40', 'True ASDS', 1, 1, 0, 1, '5e9e3032383ecb6bb234e7ca', 5.0, 8, 'B1062', -80.577366, 28.5618571, 1)]

# %%
# %%sql
# select
# case when count(outcome) from spacextbl
# group by outcome
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) near "from": syntax error
# [SQL: select
# case when count(outcome) from spacextbl
# group by outcome]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
